# %%
# %pip install request
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
url = "https://v6.exchangerate-api.com/v6/285dfe149039c038fec336df/latest/USD"
response = requests.get(url)

# %%
response.json()
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1789344002,
#  'time_last_update_utc': 'Mon, 14 Sep 2026 00:00:02 +0000',
#  'time_next_update_unix': 1789430402,
#  'time_next_update_utc': 'Tue, 15 Sep 2026 00:00:02 +0000',
#  'base_code': 'USD',
#  'conversion_rates': {'USD': 1,
#   'AED': 3.6725,
#   'AFN': 64.7672,
#   'ALL': 79.2835,
#   'AMD': 363.4739,
#   'ANG': 1.79,
#   'AOA': 921.3868,
#   'ARS': 1509.9074,
#   'AUD': 1.3967,
#   'AWG': 1.79,
#   'AZN': 1.7001,
#   'BAM': 1.6866,
#   'BBD': 2.0,
#   'BDT': 123.4267,
#   'BGN': 1.6866,
#   'BHD': 0.376,
#   'BIF': 2982.8972,
#   'BMD': 1.0,
#   'BND': 1.2671,
#   'BOB': 12.4502,
#   'BRL': 5.1204,
#   'BSD': 1.0,
#   'BTN': 95.6564,
#   'BWP': 13.7287,
#   'BYN': 3.0462,
#   'BZD': 2.0,
#   'CAD': 1.3862,
#   'CDF': 2306.1144,
#   'CHF': 0.8164,
#   'CLF': 0.02381,
#   'CLP': 940.9494,
# ...
