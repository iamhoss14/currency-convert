# %%
# %pip install request

# %%
import requests
url = "https://v6.exchangerate-api.com/v6/285dfe149039c038fec336df/latest/USD"
response = requests.get(url)

# %%
response.json()

# %%
def response_status_code(response):
    while response.status_code == 200:
        return "success"
response_status_code(response)

# %%
response

# %%
'''200 = ok
404 = not found
500 = internal server error'''

# %%
# %env EMAIL_PASSWORD=amirhossein

# %%
# %env EMAIL_USERNAME=AMIRHOSSEIN

# %%
import os
os.environ.get('EMAIL_PASSWORD'), os.environ.get('EMAIL_USERNAME')

# %%
import os
EMAIL_PASSWORD = os.environ.get('EMAIL_PASSWORD')
EMAIL_USERNAME = os.environ.get('EMAIL_USERNAME')

# %%
import requests
url = "https://jsonplaceholder.typicode.com/todos"
req = requests.get(url)
response = req.json()
response

# %%
#req.status_code
#req.apparent_encoding
#response."userId":1

# %%
import requests
url = "https://www.googleapis.com/books/v1"
response = requests.get(url)

# %%
params = {
    "q": "python programming"}
res = requests.get(url, params=params)

# %%
res.json()

# %%
import os
import requests
# %env GIPHY_API_KEY=csa31AAP10uGXOA2IpU3S15bVjmuzOmO
url = "https://api.giphy.com/v1/gifs/trending"

# %%
params = {
    'api_key': os.environ.get('GIPHY_API_KEY'),
    'limit': 5,}

# %%
res = requests.get(url, params=params)

# %%
# %pip install jsonpath-ng

# %%
import json
res.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/miniconda3/envs/nupa-env/lib/python3.10/site-packages/requests/models.py:1116, in Response.json(self, **kwargs)
#    1115 try:
# -> 1116     return complexjson.loads(self.text, **kwargs)
#    1117 except JSONDecodeError as e:
#    1118     # Catch JSON-related errors and raise as requests.JSONDecodeError
#    1119     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/miniconda3/envs/nupa-env/lib/python3.10/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~/miniconda3/envs/nupa-env/lib/python3.10/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~/miniconda3/envs/nupa-env/lib/python3.10/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[45], line 2
#       1 import json
# ----> 2 res.json()
#
# File ~/miniconda3/envs/nupa-env/lib/python3.10/site-packages/requests/models.py:1120, in Response.json(self, **kwargs)
#    1116     return complexjson.loads(self.text, **kwargs)
#    1117 except JSONDecodeError as e:
#    1118     # Catch JSON-related errors and raise as requests.JSONDecodeError
#    1119     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# -> 1120     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
